# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from datetime import datetime

# %%
from weather.data import get_dataframe
from solar_panels.historical import retrieve_data

# %%
wx = get_dataframe('data/weather-data.csv')

# %%
wx.head(3)
# Out:
#              datetime       Location Name  Temperature  Dew Point  Humidity  \
# 0 2020-08-03 00:13:00  Jaffrey, NH (KAFN)         76.0       72.0      87.0
# 1 2020-08-03 00:28:00  Jaffrey, NH (KAFN)         76.0       73.0      91.0
# 2 2020-08-03 00:41:00  Jaffrey, NH (KAFN)         76.0       72.0      87.0
#
#   Wind  Wind Speed  Wind Gust  Pressure  Precip.      Condition
# 0  SSW        12.0        0.0     28.79      0.0        Thunder
# 1  SSW        10.0        0.0     28.79      0.1     Light Rain
# 2  SSW         8.0        0.0     28.79      0.1  Mostly Cloudy

# %%
wx.dtypes
# Out:
# datetime         datetime64[ns]
# Location Name            object
# Temperature             float64
# Dew Point               float64
# Humidity                float64
# Wind                     object
# Wind Speed              float64
# Wind Gust               float64
# Pressure                float64
# Precip.                 float64
# Condition                object
# dtype: object

# %%
wx.describe()
# Out:
#        Temperature   Dew Point    Humidity  Wind Speed   Wind Gust  \
# count   982.000000  982.000000  982.000000  982.000000  982.000000
# mean     67.619145   58.733198   75.827902    3.923625    1.448065
# std       8.575595    6.813827   18.071156    3.927902    5.623133
# min      44.000000   35.000000   28.000000    0.000000    0.000000
# 25%      61.000000   55.000000   62.000000    0.000000    0.000000
# 50%      67.000000   59.000000   84.000000    3.000000    0.000000
# 75%      74.000000   64.000000   90.000000    7.000000    0.000000
# max      89.000000   73.000000  100.000000   23.000000   46.000000
#
#          Pressure     Precip.
# count  982.000000  982.000000
# mean    28.907352    0.006517
# std      0.319280    0.029579
# min     28.360000    0.000000
# 25%     28.740000    0.000000
# 50%     28.870000    0.000000
# 75%     28.990000    0.000000
# max     30.080000    0.300000

# %%
sns.pairplot(wx, hue='Location Name')
# Out:
# /srv/conda/envs/notebook/lib/python3.7/site-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)

# %%
solar = retrieve_data('data/BlueSolarHistory.csv')

# %%
solar.head(3)
# Out:
#         Date  Yield(Wh)  Max. PV power(W)  Max. PV voltage(V)  \
# 0 2020-09-02        200              61.0               32.29
# 1 2020-09-01        340             252.0               37.09
# 2 2020-08-31        320             278.0               37.47
#
#    Min. battery voltage(V)  Max. battery voltage(V)  Time in bulk(m)  \
# 0                    13.24                    13.46              743
# 1                    13.25                    14.21              583
# 2                    13.25                    14.21              574
#
#    Time in absorption(m)  Time in float(m)
# 0                      0                 0
# 1                    124                60
# 2                    120                78

# %%
solar.describe()
# Out:
#         Yield(Wh)  Max. PV power(W)  Max. PV voltage(V)  \
# count   31.000000         31.000000           31.000000
# mean   463.870968        248.838710           35.924194
# std    144.975341         66.985121            1.514073
# min    190.000000         61.000000           32.290000
# 25%    405.000000        249.500000           35.225000
# 50%    470.000000        271.000000           36.140000
# 75%    570.000000        282.500000           37.000000
# max    800.000000        321.000000           38.630000
#
#        Min. battery voltage(V)  Max. battery voltage(V)  Time in bulk(m)  \
# count                31.000000                31.000000        31.000000
# mean                 13.242581                14.052581       670.677419
# std                   0.010636                 0.299132        98.766184
# min                  13.220000                13.450000       396.000000
# 25%                  13.240000                13.940000       611.000000
# ...

# %%
solar.dtypes
# Out:
# Date                       datetime64[ns]
# Yield(Wh)                           int64
# Max. PV power(W)                  float64
# Max. PV voltage(V)                float64
# Min. battery voltage(V)           float64
# Max. battery voltage(V)           float64
# Time in bulk(m)                     int64
# Time in absorption(m)               int64
# Time in float(m)                    int64
# dtype: object

# %%
sns.pairplot(solar)
